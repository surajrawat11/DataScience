# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# IPL 2026 Data Visualization Project\n",
    "\n",
    "The Indian Premier League (IPL) 2026 season brought fireworks with young sensation **Vaibhav Sooryavanshi** rewriting the record books. This project explores IPL 2026 match-level, player-level, and ball-by-ball data to uncover insights on team performance, standout players, venues, and match trends.\n",
    "\n",
    "**Datasets used:**\n",
    "| File | Description |\n",
    "|---|---|\n",
    "| `matches.csv` | Match-by-match results, toss, scores, POTM |\n",
    "| `points_table.csv` | League standings |\n",
    "| `batting_stats.csv` | Leading run-scorers leaderboard |\n",
    "| `bowling_stats.csv` | Leading wicket-takers leaderboard |\n",
    "| `fielding_stats.csv` | Leading catch-takers leaderboard |\n",
    "| `deliveries.csv` | Ball-by-ball data for every match |\n",
    "| `squads.csv` | Full playing squads for all 10 franchises |\n",
    "| `venues.csv` | Stadium info (city, capacity, home team) |\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Loading the Libraries and Datasets"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import numpy as np\n",
    "import pandas as pd\n",
    "import seaborn as sns\n",
    "import matplotlib.pyplot as plt\n",
    "import warnings\n",
    "warnings.filterwarnings(\"ignore\")\n",
    "\n",
    "sns.set_style(\"whitegrid\")\n",
    "plt.rcParams['figure.figsize'] = (9, 5)\n",
    "\n",
    "matches   = pd.read_csv('matches.csv')\n",
    "points    = pd.read_csv('points_table.csv')\n",
    "batting   = pd.read_csv('batting_stats.csv')\n",
    "bowling   = pd.read_csv('bowling_stats.csv')\n",
    "fielding  = pd.read_csv('fielding_stats.csv')\n",
    "deliveries = pd.read_csv('deliveries.csv')\n",
    "squads    = pd.read_csv('squads.csv')\n",
    "venues    = pd.read_csv('venues.csv')\n",
    "\n",
    "matches.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "stream",
     "name": "stdout",
     "text": [
      "Matches     : (39, 23)\n",
      "Points table: (10, 9)\n",
      "Batting     : (15, 17)\n",
      "Bowling     : (15, 17)\n",
      "Fielding    : (15, 6)\n",
      "Deliveries  : (17477, 19)\n",
      "Squads      : (257, 6)\n",
      "Venues      : (12, 5)\n"
     ]
    }
   ],
   "source": [
    "print(\"Matches     :\", matches.shape)\n",
    "print(\"Points table:\", points.shape)\n",
    "print(\"Batting     :\", batting.shape)\n",
    "print(\"Bowling     :\", bowling.shape)\n",
    "print(\"Fielding    :\", fielding.shape)\n",
    "print(\"Deliveries  :\", deliveries.shape)\n",
    "print(\"Squads      :\", squads.shape)\n",
    "print(\"Venues      :\", venues.shape)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Data Quality Check\n",
    "\n",
    "A quick null check across the core datasets so we know what we're working with before analysis."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "stream",
     "name": "stdout",
     "text": [
      "Missing values in matches.csv:\n",
      "first_ings_score        1\n",
      "first_ings_wkts         1\n",
      "second_ings_score       1\n",
      "second_ings_wkts        1\n",
      "match_winner            1\n",
      "wb_runs                24\n",
      "wb_wickets             17\n",
      "balls_left              1\n",
      "player_of_the_match     1\n",
      "top_scorer              1\n",
      "highscore               1\n",
      "best_bowling            1\n",
      "best_bowling_figure     1\n",
      "dtype: int64\n"
     ]
    }
   ],
   "source": [
    "print(\"Missing values in matches.csv:\")\n",
    "print(matches.isnull().sum()[matches.isnull().sum() > 0])"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "Some matches have missing `match_winner`/`highscore`/`best_bowling` fields \u2014 these correspond to an **abandoned** match (no result), which we'll account for below."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "matches['match_result'].value_counts()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Points Table \u2014 Where Every Team Stands"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "standings = points.sort_values('points', ascending=False)\n",
    "\n",
    "fig, ax = plt.subplots(figsize=(9,5))\n",
    "sns.barplot(data=standings, y='team', x='points', hue='team', palette='viridis', legend=False, ax=ax)\n",
    "for i, (pts, nrr) in enumerate(zip(standings['points'], standings['nrr'])):\n",
    "    ax.text(pts + 0.1, i, f\"NRR {nrr:+.3f}\", va='center', fontsize=9)\n",
    "ax.set_title(\"IPL 2026 Points Table \u2014 Standings (bar length = points)\")\n",
    "ax.set_xlabel(\"Points\")\n",
    "ax.set_ylabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "wl = standings.set_index('team')[['wins','defeats','ties']]\n",
    "wl.plot(kind='barh', stacked=True, color=['#2ecc71','#e74c3c','#95a5a6'], figsize=(9,5))\n",
    "plt.title(\"Wins vs Defeats vs Ties by Team\")\n",
    "plt.xlabel(\"Matches\")\n",
    "plt.ylabel(\"\")\n",
    "plt.legend(title=\"Result\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Match Trends"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "match_wins = matches['match_winner'].value_counts()\n",
    "sns.barplot(y=match_wins.index, x=match_wins.values, hue=match_wins.index, palette='mako', legend=False)\n",
    "plt.title(\"Match Wins by Team (League Stage)\")\n",
    "plt.xlabel(\"Wins\")\n",
    "plt.ylabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "sns.countplot(x=matches['toss_decision'], hue=matches['toss_decision'], palette='rainbow', legend=False)\n",
    "plt.title(\"Toss Decision Trends \u2014 Bat vs Bowl First\")\n",
    "plt.xlabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "stream",
     "name": "stdout",
     "text": [
      "Toss winner also won the match in 21 of 38 completed matches (55.26%)\n"
     ]
    }
   ],
   "source": [
    "valid = matches.dropna(subset=['match_winner'])\n",
    "toss_match_same = (valid['toss_winner'] == valid['match_winner']).sum()\n",
    "pct = round(toss_match_same * 100 / len(valid), 2)\n",
    "print(f\"Toss winner also won the match in {toss_match_same} of {len(valid)} completed matches ({pct}%)\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "sns.countplot(x=matches['match_result'], hue=matches['match_result'], palette='Set2', legend=False)\n",
    "plt.title(\"Match Result Type (won_by / no-result)\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5. Venue Analysis"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "venue_count = matches['venue'].value_counts()\n",
    "sns.barplot(y=venue_count.index, x=venue_count.values, hue=venue_count.index, palette='crest', legend=False)\n",
    "plt.title(\"Matches Played by Venue\")\n",
    "plt.xlabel(\"Matches\")\n",
    "plt.ylabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "v_sorted = venues.sort_values('capacity', ascending=False)\n",
    "sns.barplot(data=v_sorted, y='venue_stadium', x='capacity', hue='home_team', dodge=False, palette='flare')\n",
    "plt.title(\"Stadium Capacity by Venue (colored by home franchise)\")\n",
    "plt.xlabel(\"Capacity\")\n",
    "plt.ylabel(\"\")\n",
    "plt.legend(title=\"Home Team\", bbox_to_anchor=(1.02,1), loc='upper left')\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 6. Key Player Performances \u2014 Batting"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "batting.sort_values('runs', ascending=False)[['batsman','team','runs','average','strike_rate','hundreds','fifties']].head(10)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "top_runs = batting.sort_values('runs', ascending=False).head(10)\n",
    "sns.barplot(data=top_runs, y='batsman', x='runs', hue='team', dodge=False, palette='rocket')\n",
    "plt.title(\"Orange Cap Race \u2014 Top 10 Run Scorers, IPL 2026\")\n",
    "plt.xlabel(\"Runs\")\n",
    "plt.ylabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "fig, ax = plt.subplots(figsize=(9,6))\n",
    "sns.scatterplot(data=batting, x='average', y='strike_rate', size='runs', hue='team',\n",
    "                 sizes=(50,400), alpha=0.8, ax=ax)\n",
    "for _, r in batting.iterrows():\n",
    "    if r['runs'] > 250:\n",
    "        ax.text(r['average']+0.5, r['strike_rate'], r['batsman'], fontsize=8)\n",
    "ax.set_title(\"Batting Average vs Strike Rate (bubble size = runs scored)\")\n",
    "ax.legend(bbox_to_anchor=(1.02,1), loc='upper left', fontsize=8)\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "top_boundaries = batting.sort_values('runs', ascending=False).head(10).set_index('batsman')[['fours','sixes']]\n",
    "top_boundaries.plot(kind='bar', stacked=True, color=['#3498db','#e67e22'], figsize=(9,5))\n",
    "plt.title(\"Boundary Breakdown \u2014 Fours vs Sixes (Top 10 Run Scorers)\")\n",
    "plt.ylabel(\"Count\")\n",
    "plt.xlabel(\"\")\n",
    "plt.xticks(rotation=40, ha='right')\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 7. Key Player Performances \u2014 Bowling"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "bowling.sort_values('wickets', ascending=False)[['bowler','team','wickets','economy','bbi','avg']].head(10)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "top_wkts = bowling.sort_values('wickets', ascending=False).head(10)\n",
    "sns.barplot(data=top_wkts, y='bowler', x='wickets', hue='team', dodge=False, palette='mako')\n",
    "plt.title(\"Purple Cap Race \u2014 Top 10 Wicket Takers, IPL 2026\")\n",
    "plt.xlabel(\"Wickets\")\n",
    "plt.ylabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "econ_qualified = bowling[bowling['overs'] >= 20].sort_values('economy').head(10)\n",
    "sns.barplot(data=econ_qualified, y='bowler', x='economy', hue='team', dodge=False, palette='crest')\n",
    "plt.title(\"Best Economy Rate (min. 20 overs bowled)\")\n",
    "plt.xlabel(\"Economy Rate\")\n",
    "plt.ylabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 8. Fielding \u2014 Catch Takers"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "top_catches = fielding.sort_values('catches', ascending=False).head(10)\n",
    "sns.barplot(data=top_catches, y='player', x='catches', hue='team', dodge=False, palette='viridis')\n",
    "plt.title(\"Most Catches, IPL 2026\")\n",
    "plt.xlabel(\"Catches\")\n",
    "plt.ylabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 9. Ball-by-Ball Insights (`deliveries.csv`)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "def phase(over):\n",
    "    if over < 6: return 'Powerplay (1-6)'\n",
    "    elif over < 16: return 'Middle (7-16)'\n",
    "    else: return 'Death (17-20)'\n",
    "\n",
    "deliveries['over_num'] = deliveries['over'].astype(int)\n",
    "deliveries['phase'] = deliveries['over_num'].apply(phase)\n",
    "\n",
    "runs_col = deliveries['runs_of_bat'] + deliveries['extras']\n",
    "phase_runs = deliveries.groupby('phase')[['runs_of_bat']].sum()\n",
    "phase_balls = deliveries.groupby('phase').size()\n",
    "phase_rr = (phase_runs['runs_of_bat'] / (phase_balls/6)).reindex(['Powerplay (1-6)','Middle (7-16)','Death (17-20)'])\n",
    "\n",
    "sns.barplot(x=phase_rr.index, y=phase_rr.values, hue=phase_rr.index, palette='flare', legend=False)\n",
    "plt.title(\"Run Rate by Match Phase (Tournament-wide)\")\n",
    "plt.ylabel(\"Runs per Over\")\n",
    "plt.xlabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "wickets = deliveries.dropna(subset=['wicket_type'])\n",
    "wtype = wickets['wicket_type'].value_counts()\n",
    "plt.pie(wtype.values, labels=wtype.index, autopct='%1.1f%%', startangle=90,\n",
    "        colors=sns.color_palette('Set3', len(wtype)))\n",
    "plt.title(\"Dismissal Type Distribution\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "sixes_by_over = deliveries[deliveries['runs_of_bat']==6].groupby('over_num').size()\n",
    "fours_by_over = deliveries[deliveries['runs_of_bat']==4].groupby('over_num').size()\n",
    "boundary_df = pd.DataFrame({'Fours': fours_by_over, 'Sixes': sixes_by_over}).fillna(0)\n",
    "\n",
    "boundary_df.plot(kind='bar', stacked=True, color=['#3498db','#e67e22'], figsize=(11,5))\n",
    "plt.title(\"Boundary Meter \u2014 Fours & Sixes by Over Number (Tournament-wide)\")\n",
    "plt.xlabel(\"Over Number\")\n",
    "plt.ylabel(\"Count\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "top_bowlers_hit = deliveries[deliveries['runs_of_bat']==6]['bowler'].value_counts().head(10)\n",
    "sns.barplot(y=top_bowlers_hit.index, x=top_bowlers_hit.values, hue=top_bowlers_hit.index, palette='rocket', legend=False)\n",
    "plt.title(\"Bowlers Who Conceded the Most Sixes\")\n",
    "plt.xlabel(\"Sixes Conceded\")\n",
    "plt.ylabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 10. Squad Composition"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "nat_counts = squads['nationality'].value_counts()\n",
    "plt.pie(nat_counts.values, labels=nat_counts.index, autopct='%1.1f%%', startangle=90,\n",
    "        colors=['#2ecc71','#3498db'])\n",
    "plt.title(\"Indian vs Overseas Players Across All Squads\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "role_by_team = pd.crosstab(squads['team_name'], squads['role'])\n",
    "role_by_team.plot(kind='bar', stacked=True, colormap='tab20', figsize=(11,6))\n",
    "plt.title(\"Squad Role Composition by Team\")\n",
    "plt.ylabel(\"Number of Players\")\n",
    "plt.xlabel(\"\")\n",
    "plt.xticks(rotation=40, ha='right')\n",
    "plt.legend(title=\"Role\", bbox_to_anchor=(1.02,1), loc='upper left')\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "overseas_pct = (squads[squads['nationality']=='Overseas'].groupby('team_name').size() /\n",
    "                squads.groupby('team_name').size() * 100).sort_values(ascending=False)\n",
    "sns.barplot(y=overseas_pct.index, x=overseas_pct.values, hue=overseas_pct.index, palette='mako', legend=False)\n",
    "plt.title(\"Overseas Player Share by Squad (%)\")\n",
    "plt.xlabel(\"% Overseas Players\")\n",
    "plt.ylabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 11. Custom Questions & Insights"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "**Q1: Which match had the highest winning margin by runs?**"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "matches[matches['match_result']=='completed'].query(\"wb_runs == wb_runs.max()\")[['match_winner','wb_runs','team1','team2']]"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "**Q2: Who scored the highest individual score of the tournament, and does it match the README's record?**"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "matches[matches['highscore'] == matches['highscore'].max()][['top_scorer','highscore','team1','team2']]"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "**Q3: Which bowling performance was the best of the season?**"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "matches['wkts_taken'] = matches['best_bowling_figure'].dropna().apply(lambda x: int(x.split('--')[0]))\n",
    "matches[matches['wkts_taken'] == matches['wkts_taken'].max()][['best_bowling','best_bowling_figure','team1','team2']]"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "**Q4: Which venue has hosted the highest-scoring matches on average (first innings score)?**"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "matches.dropna(subset=['first_ings_score']).groupby('venue')['first_ings_score'].mean().sort_values(ascending=False).round(1).head(5)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "**Q5: How many Player-of-the-Match awards has each player won, and who leads?**"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [
    {
     "output_type": "execute_result",
     "execution_count": null,
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure>"
      ]
     },
     "metadata": {}
    }
   ],
   "source": [
    "potm = matches['player_of_the_match'].value_counts().head(10)\n",
    "sns.barplot(y=potm.index, x=potm.values, hue=potm.index, palette='cubehelix', legend=False)\n",
    "plt.title(\"Most Player-of-the-Match Awards\")\n",
    "plt.xlabel(\"Awards\")\n",
    "plt.ylabel(\"\")\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 12. Summary \u2014 IPL 2026 Season Highlights\n",
    "\n",
    "Pulled together from across the datasets analyzed above:\n",
    "\n",
    "- **Player of the Tournament (MVP):** Vaibhav Sooryavanshi (RR)\n",
    "- **Orange Cap (Most Runs):** Vaibhav Sooryavanshi (RR) \u2014 776 runs\n",
    "- **Purple Cap (Most Wickets):** Kagiso Rabada (GT) \u2014 29 wickets\n",
    "- **Highest Individual Score:** KL Rahul (DC) \u2014 152* vs PBKS\n",
    "- **Best Bowling Economy:** Sunil Narine (KKR) \u2014 6.64\n",
    "- **Most Sixes:** Vaibhav Sooryavanshi (RR) \u2014 72 sixes\n",
    "- **Highest Total:** PBKS \u2014 265/4 vs DC\n",
    "- **Lowest Total:** DC \u2014 75/10 vs RCB\n",
    "- **Centuries in the Tournament:** 14\n",
    "\n",
    "*Note: the datasets in this notebook capture the league stage (39 matches); the season highlights above reflect the full-season records as published.*\n",
    "\n",
    "### Good Work! \ud83c\udfcf\n"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}IPL_2026.ipynb
# Out:
#   Cell In[1], line 946
#     }IPL_2026.ipynb
#      ^
# SyntaxError: invalid syntax
